# %%
import requests

# %%
proxies = {
  'http': 'http://localhost:8080',
  'https': 'https://localhost:8080',
}
response = requests.get('http://www.flipkart.com/',proxies=proxies)
print ('status code:', response.status_code)
print ('content length:', response.headers['content-length'])
print (response.text)
# Out:
# ('status code:', 200)
# ('content length:', '33277')
# <!DOCTYPE html>
# <!-- saved from url=(0081)https://cmpe.sjsu.edu/content/masters-in-computer-engineering/Degree-Requirements -->
# <html lang="en" class="no-js js"><!--<![endif]--><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#
# <link rel="shortcut icon" href="https://cmpe.sjsu.edu/sites/all/themes/sjsu/favicon.ico">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="description" content="To obtain the MS CMPE degree from SJSU, a student must meet the following requirements: ÃÂ   1.ÃÂ Classification RequirementÃÂ  The student must be a classified MS CMPE student, as described in Section 5.3: Admission Conditions. ÃÂ  2. Course RequirementÃÂ  The student must complete course work in three categories: ÃÂ  Program Core Courses (courses that all MS CMPE students are required to take):">
# ...
